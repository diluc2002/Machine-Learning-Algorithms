# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
data_set=pd.read_csv("apple_quality1.csv")
x=data_set.iloc[:,[1,2]].values
y=data_set.iloc[:,8].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)
st_x=StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.transform(x_test)

classifier=LogisticRegression()
classifier.fit(x_train,y_train)

y_pred=classifier.predict(x_test)
print(y_pred)
# Out:
# ['bad' 'good' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'good' 'bad'
#  'good' 'bad' 'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'bad' 'bad'
#  'good' 'good' 'bad' 'good' 'good' 'bad' 'bad' 'bad' 'bad' 'good' 'bad'
#  'good' 'good' 'bad' 'good' 'bad' 'good' 'good' 'bad' 'good' 'good' 'bad'
#  'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'good' 'bad'
#  'bad' 'good' 'good' 'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'bad'
#  'good' 'good' 'bad' 'good' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good'
#  'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'good' 'bad' 'good'
#  'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'bad' 'bad' 'bad'
#  'good' 'good' 'good' 'bad' 'bad' 'good' 'bad' 'bad' 'bad' 'good' 'good'
#  'good' 'good' 'good' 'good' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'bad'
#  'bad' 'bad' 'good' 'good' 'good' 'bad' 'bad' 'bad' 'bad' 'bad' 'bad'
#  'bad' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'bad' 'good' 'bad' 'bad'
#  'bad' 'bad' 'good' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'bad' 'bad'
#  'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'good' 'bad' 'good' 'good'
#  'bad' 'bad' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'bad' 'good'
#  'bad' 'bad' 'good' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'bad' 'bad'
#  'good' 'good' 'good' 'bad' 'good' 'good' 'bad' 'good' 'bad' 'bad' 'bad'
#  'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good'
#  'good' 'good' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'good'
#  'good' 'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'good' 'bad' 'bad'
#  'good' 'good' 'bad' 'bad' 'good' 'good' 'good' 'good' 'bad' 'bad' 'bad'
#  'bad' 'good' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'bad' 'bad'
#  'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'bad'
#  'bad' 'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'good' 'bad' 'good'
#  'good' 'bad' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'good'
#  'bad' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'bad' 'bad'
#  'bad' 'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'bad'
#  'bad' 'good' 'good' 'bad' 'bad' 'good' 'good' 'good' 'good' 'bad' 'good'
#  'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'good'
#  'good' 'bad' 'bad' 'good' 'bad' 'good' 'good' 'bad' 'good' 'bad' 'good'
#  'bad' 'bad' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'good' 'good'
#  'good' 'good' 'good' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'good'
#  'bad' 'good' 'bad' 'good' 'bad' 'good' 'bad' 'bad' 'good' 'good' 'good'
#  'bad' 'good' 'good' 'bad' 'bad' 'good' 'good' 'good' 'good' 'good' 'bad'
#  'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'good' 'bad' 'bad'
#  'bad' 'good' 'bad' 'good']

# %%
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(classifier.fit(x_test,y_test),x_test,cmap=plt.cm.RdYlBu,response_method='predict')
rgb_one = (np.random.rand(),np.random.rand(),np.random.rand())
rgb_two = (np.random.rand(),np.random.rand(),np.random.rand())
color_array = []
color_array.append(rgb_one)
color_array.append(rgb_two)
for i,j in enumerate(np.unique(y_test)):
    plt.scatter(x_test[y_test==j,0],x_test[y_test==j,1],color=color_array[i],label=j)
plt.title("Logistic Regression")
plt.show()

# %%
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(classifier.fit(x_train,y_train),x_train,cmap=plt.cm.RdYlBu,response_method='predict')
rgb_one = (np.random.rand(),np.random.rand(),np.random.rand())
rgb_two = (np.random.rand(),np.random.rand(),np.random.rand())
color_array = []
color_array.append(rgb_one)
color_array.append(rgb_two)
for i,j in enumerate(np.unique(y_train)):
    plt.scatter(x_train[y_train==j,0],x_train[y_train==j,1],color=color_array[i],label=j)
plt.title("Logistic Regression")
plt.xlabel(data_set.columns[2])
plt.ylabel(data_set.columns[8])
plt.legend()
plt.show()
