# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

dataset=pd.read_csv("apple_quality1.csv")
x=dataset.iloc[:,[1,7]].values
y=dataset.iloc[:,8].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.07,random_state=0)
std=StandardScaler()
x_train=std.fit_transform(x_train)
x_test=std.transform(x_test)

classifier=KNeighborsClassifier()
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

print(y_pred)
# Out:
# ['good' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'bad'
#  'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'good' 'good' 'bad' 'bad' 'bad'
#  'good' 'good' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'bad' 'bad' 'good'
#  'bad' 'good' 'good' 'bad' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'bad'
#  'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'good' 'good'
#  'bad' 'bad' 'good' 'good' 'good' 'good' 'bad' 'bad' 'good' 'good' 'good'
#  'good' 'good' 'bad' 'bad' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'bad'
#  'good' 'good' 'bad' 'bad' 'good' 'good' 'good' 'bad' 'good' 'bad' 'bad'
#  'good' 'bad' 'good' 'good' 'good' 'bad' 'bad' 'bad' 'good' 'bad' 'bad'
#  'good' 'bad' 'good' 'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'good'
#  'bad' 'good' 'bad' 'good' 'good' 'good' 'good' 'bad' 'good' 'good' 'good'
#  'bad' 'good' 'good' 'good' 'good' 'good' 'good' 'good' 'bad' 'good' 'bad'
#  'bad' 'good' 'good' 'good' 'bad' 'good' 'bad' 'good' 'bad' 'good' 'good'
# ...

# %%
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(classifier.fit(x_test,y_test),x_test,cmap=plt.cm.YlGnBu,alpha=1,response_method='predict')
rgb_one=(np.random.rand(),np.random.rand(),np.random.rand())
rgb_two=(np.random.rand(),np.random.rand(),np.random.rand())
color_array = []
color_array.append(rgb_one)
color_array.append(rgb_two)
for i,j in enumerate(np.unique(y_test)):
    plt.scatter(x_test[y_test==j,0],x_test[y_test==j,1],color=color_array[i],label=j)
plt.title("K Neighbors")
plt.xlabel(dataset.columns[1])
plt.ylabel(dataset.columns[7])
plt.legend()
plt.show()

# %%
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(classifier.fit(x_train,y_train),x_test,cmap=plt.cm.magma,response_method='predict')
rgb_one=(np.random.rand(),np.random.rand(),np.random.rand())
rgb_two=(np.random.rand(),np.random.rand(),np.random.rand())
color_array = []
color_array.append(rgb_one)
color_array.append(rgb_two)
for i,j in enumerate(np.unique(y_test)):
    plt.scatter(x_test[y_test==j,0],x_test[y_test==j,1],color=color_array[i],label=j)
plt.title("K Neighbors")
plt.xlabel(dataset.columns[1])
plt.ylabel(dataset.columns[7])
plt.legend()
plt.show()
